# %%
# Author: Kevin Roy Maglaqui
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('job_posting_clean.csv')

# %% [markdown]
# # Which job postings receive the most applications?

# %%
#list all the number of applications
#df.applies.to_string(index=False)
most_applications = df.loc[df['applies'].idxmax()]

# Graph of the most applied jobs
top_jobs = df.nlargest(10, 'applies')
plt.figure(figsize=(12,6))
sns.barplot(x='applies', y='title', data=top_jobs, palette='viridis')
plt.title("Most applied Jobs (July 2023-November 2023)")
plt.xlabel("Applications")
plt.ylabel("Job Title")
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_25288\4153541234.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='applies', y='title', data=top_jobs, palette='viridis')

# %% [markdown]
# # Is there a correlation of jobs between salary and job views/applications?

# %%
# Group by job title and calculate the average salary, views, and applications
grouped_df = df.groupby('title')[['yearly_med_salary', 'applies']].mean().reset_index()

correlation_applies_salary = grouped_df['yearly_med_salary'].corr(grouped_df['applies'])

print(f"Correlation between Salary and Applications: {correlation_applies_salary:.2f}")

plt.scatter(grouped_df['applies'], grouped_df['yearly_med_salary'], alpha=0.6, color="royalblue")
plt.title('Salary vs Applications by Job Title')
plt.xlabel('Average Applications')
plt.ylabel('Average Salary (USD)')
plt.grid(True)

print(c)

plt.show()
# Out:
# Correlation between Salary and Applications: 0.07
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 plt.ylabel('Average Salary (USD)')
#      12 plt.grid(True)
# ---> 14 print(c)
#      16 plt.show()
#
# NameError: name 'c' is not defined

# %% [markdown]
# How do job applications differ across experience levels?

# %%
# Group by experience level and calculate the average number of applications
experience_applies = df.groupby("formatted_experience_level")["applies"].mean().reset_index()

# Sort experience levels for better visualization
experience_applies = experience_applies.sort_values(by="applies", ascending=False)

# Plot job applications by experience level
plt.figure(figsize=(10, 6))
plt.barh(experience_applies["formatted_experience_level"], experience_applies["applies"], color="skyblue")
plt.xlabel("Average Applications")
plt.ylabel("Experience Level")
plt.title("Job Applications Across Experience Levels")
plt.gca().invert_yaxis()  # Invert the y-axis to display the highest number of applications on top
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Show the plot
plt.show()
